# %%
import pandas as pd

# %%
num5=pd.read_csv('num5.csv')

# %%
num5.head()
# Out:
#    Unnamed: 0 codigo_curso                             curso  \
# 0           0         9181                          História
# 1           1         9164  Gestão e Administração Hoteleira
# 2           2         9147                            Gestão
# 3           3         9741              Engenharia Automóvel
# 4           4         8296                 Gestão Industrial
#
#    codigo_estabelecimento                  estabelecimento  \
# 0                     505          Universidade de Coimbra
# 1                    3139   Instituto Politécnico do Porto
# 2                     300           Universidade de Aveiro
# 3                    3102  Instituto Politécnico de Leiria
# 4                    3182   Instituto Politécnico de Viseu
#
#                                             escola  regime_pos_laboral  \
# 0                              Faculdade de Letras                   0
# 1           Escola Superior de Hotelaria e Turismo                   0
# ...

# %%
num5[(num5['curso'] == 'Engenharia Mecânica') & (num5['estabelecimento'] == 'Universidade do Porto')]
# Out:
#      Unnamed: 0 codigo_curso                curso  codigo_estabelecimento  \
# 759         759         9123  Engenharia Mecânica                    1105
#
#            estabelecimento                   escola  regime_pos_laboral  \
# 759  Universidade do Porto  Faculdade de Engenharia                   0
#
#      regime_noturno  total_candidatos_1op  total_colocados_1op  \
# 759               0                   259                  127
#
#      proporcao_colocados
# 759                 49.0

# %%
colocados=pd.read_csv('colocados.csv')

# %%
colocados.head()
# Out:
#    Unnamed: 0  codigo_estabelecimento          estabelecimento  \
# 0           0                     140  Universidade dos Açores
# 1           1                     140  Universidade dos Açores
# 2           2                     140  Universidade dos Açores
# 3           3                     140  Universidade dos Açores
# 4           4                     140  Universidade dos Açores
#
#                                          escola codigo_curso  \
# 0  Faculdade de Ciências Agrárias e do Ambiente         9022
# 1  Faculdade de Ciências Agrárias e do Ambiente         9022
# 2  Faculdade de Ciências Agrárias e do Ambiente         9022
# 3  Faculdade de Ciências Agrárias e do Ambiente         9022
# 4  Faculdade de Ciências Agrárias e do Ambiente         9022
#
#                curso                            Nome          cc  \
# 0  Ciências Agrárias            BERNARDO COUTO MATOS  150(...)35
# 1  Ciências Agrárias             ISAC SILVA MENDONÇA  158(...)81
# ...

# %%
colocados[(colocados['curso'] == 'Ciências da Computação') & (colocados['estabelecimento'] == 'Universidade do Minho')]
# Out:
#        Unnamed: 0  codigo_estabelecimento        estabelecimento escola  \
# 12039       12039                    1000  Universidade do Minho      D
# 12040       12040                    1000  Universidade do Minho      D
# 12041       12041                    1000  Universidade do Minho      D
# 12042       12042                    1000  Universidade do Minho      D
# 12043       12043                    1000  Universidade do Minho      D
# ...           ...                     ...                    ...    ...
# 12111       12111                    1000  Universidade do Minho      D
# 12112       12112                    1000  Universidade do Minho      D
# 12113       12113                    1000  Universidade do Minho      D
# 12114       12114                    1000  Universidade do Minho      D
# 12115       12115                    1000  Universidade do Minho      D
#
#       codigo_curso                   curso  \
# 12039         9397  Ciências da Computação
# ...
